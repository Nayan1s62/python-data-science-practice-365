# %% [markdown]
# # Here are 30 Questions on Python Functions (Categorized by Type)

# %%
# 1-5: Functions with No Parameters

# %% [markdown]
# # 1. Write a function greet() that prints "Hello, Welcome to Python!".

# %%
def greet( ):
    return "Hello, Welcome to Python!"

# %%
greet()
# Out:
# 'Hello, Welcome to Python!'

# %%
# 2. Create a function show_date() that prints the current date and time.

# %%
def show_date(date = " " ,time=" " ):
     return f" The current date is  {date} and time is {time}"

# %%
show_date(date = "3 june", time = "3:30 Am ")
# Out:
# ' the current date is  3 june and time is 3:30 Am '

# %%
# 3. Write a function print_square() that prints the square of numbers from 1 to 10.

# %%
def print_square():
     for i in range (1,11):
             print( i**2 )

# %%
print_square()
# Out:
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100

# %%
# 4. Make a function motivation() that prints any motivational quote.

# %%
def  motivation():
    return "power full peoples make powerfull empires"

# %%
motivation()
# Out:
# 'power full peoples make powerfull empires'

# %%
# 5. Write a function line() that prints 50 dashes (-).

# %%
def line( ):
    return"-" * 50

# %%
line()
# Out:
# '--------------------------------------------------'

# %%
# 6-12: Functions with Default Parameters

# %%
    def default_para(name = "shravan"):
        return f" this is {name} in my collage "

# %%
default_para(name = "Nayan")
# Out:
# ' this is Nayan in my collage '

# %%
# 6. Write a function greet_user(name="Guest") that greets the user.

# %%
def greet_user(name= "Guest"):
    print(f"hello {name}")

# %%
greet_user(name= "Guest" )
# Out:
# hello Guest

# %%
def greet_user(name= "Guest"):
    return(f"hello {name}")

# %%
 greet_user(name= "Guest")
# Out:
# 'hello Guest'

# %%
def greet_user(name= "Guest"):
    return(f"hello {name}")

# %%
greet_user(name= "Guest")
# Out:
# 'hello Guest'

# %% [markdown]
# # 7. Create a function power(base, exp=2) that returns base raised to exp.

# %%
def power(base,exp=2):
    c = base * 2:
    print " f"this is base {base} * exp= {exp}"

# %%
power(base=5,exp=2)
# Out:
# 'this is base 5 * exp= 2'

# %%
# 8. Write a function student_info(name, age=18, city="Delhi").

# %%
def student_info(name, age=18, city="Delhi"):
    return f" my name is {name}\nand my current age is: {age} \ni am from: {city}\n:"

# %%
student_info(name="nayan ", age=18, city="Delhi")
# Out:
# ' my name is nayan \nand my current age is: 18 \ni am from: Delhi\n:'

# %%
# 9. Make a function add_numbers(a, b=0, c=0) that returns sum of three numbers.

# %%
def add_numbers(a, b=10, c=0):
   return a + b + c

# %%
add_numbers(a=1)
# Out:
# 11

# %%
# 10. Write a function repeat_message(msg, times=3) that prints message times times.

# %%
def  repeat_message(msg, times= 3 ):
         return 3 * msg

# %%
repeat_message(msg = "hello  ", times=3 )
# Out:
# 'hello  hello  hello  '

# %%
# 12. Write a function introduce(name="Unknown", profession="Student").

# %%
def introduce(name="Unknown", profession="Student"):
    return f"The registered name of the guy is {name} and by profession {profession}"

# %%
introduce("nayan")
# Out:
# 'The registered name of the guy is nayan and by profession Student'

# %%
# 13-18: Positional Arguments & Keyword Arguments

# %%
# 13. Write a function full_name(first, last) and call it using positional arguments.

# %%
def full_name(first,last):
    return f"{first},{last} "

# %%
full_name("nayan","Samrutwar")
# Out:
# 'nayan,Samrutwar '

# %%
# 14. Call the same function using keyword arguments.

# %%
def info_data(name,age,city,mob_no,profession):
    return f"my current name {name} and i am around {age} years old my ph-no is {mob_no} i am currently doing {profession} "

# %%
info_data(name= "abbdulla raheman ",age= 22 ,city = "nagpur",mob_no= 7775046467,profession="software engneering ")
# Out:
# 'my current name ab and i am around 22 years old my ph-no is 7775046467 i am currently doing software engneering  '

# %%
# 15. Write a function details(name, age, city) and demonstrate both positional and keyword
# calls.

# %%
def  details(name, age, city):
    return f"this is {name} this is my {age} this is {city} "

# %%
details(city = "ngp")
