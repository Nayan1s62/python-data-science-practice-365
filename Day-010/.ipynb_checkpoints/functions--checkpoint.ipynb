# %%
# 3 syntax of the methods comprehensive

# %%
# 2 tpyes of function in python 
# 1)inbuilt function 
# 2)user define function 
# def

# %%
# functions ;-  reuseable block of code that perfroms a specific task you defined it once 

#syntax  : - 

def function_name(parameter):  # we take input here 

    # block of code         code logic if else condictions

# %%
# addition of two number function
# return print & store 
# if use print can not store it 
# (a,b) - arrguments

# %%
 
def addition_number(a,b):
    c = a + b
    return c

# %%
#  calling function 
 # addition_number(12,11) using parameters

# %%
# add = addition_number(12,11)

# %%
add
# Out:
# 23

# %%
addition_number(12,11)
# Out:
# 23

# %%
# chek the even odd function 
# num part is arrgumants # this argu.. function part is used

# %%
def check_even_odd(num):

    if num % 2 == 0 :
        return"even"
    else:
        return"odd"

# %%
# calling the function 
check_even_odd(2)
# Out:
# 'even'

# %%
def math_operation(i):

    if i > 0 :
        return"positive"

    else:
        return"negative"

# %%
math_operation(10)
# Out:
# 'positive'

# %%
 # types of parameter 
# type 1 No parameter function :
def hello_(good_morning = ""):
    return hello_

# %%
hello_(10)
# Out:
# <function __main__.hello_(good_morning)>

# %%
 # type 2 : positional parameters 

def info(name,age):

    return f"my name is {name} and age is {age}"

# %%
info("punit",24)
# Out:
# 'my name is punit and age is 24'

# %% [markdown]
# # Type 3 : Default parameter

# %%
def hello(name = "nayan"):
    return f"my {name} naam kafi  hai "
hello("Rohit")
# Out:
# 'my Rohit naam kafi  hai '

# %%
# key argument

# %%
 def info(name,age,mob_no):
     return f"my {name} and  age  is  {age} is and phno {mob_no}"

# %%
info(name= "punit",age="12", mob_no=123)
# Out:
# 'my punit is my 12is and phno 123'

# %%
info(mob_no=123,age="12", name= "punit")      # it also arrgument +  values
# Out:
# 'my punit is my 12 is and phno 123'

# %%
# take name , adress ,city , cour

# %%
 def info(name,address,city,course,mentor_name):
     return f"my name is: {name} \nand i am from: {address} \nmy enroll course is:   {course} \nmy mentor of the course is:  {mentor_name} \nmy mentor is him:"

# %%
info(name= "nayan", address ="plot 8 c dighori villa no 8", city= "nagpur ",course= "DS",mentor_name = 'sumit sir sartale' )
# Out:
# ' my name is  nayan \nand i am from: plot 8 c dighori villa no 8 \nmy enroll course is:   DS \nmy mentor of the course is:  sumit sir sartale \nmy mentor is him:'

# %%
#  Type 5 - argus (multiple position )

# %%
def add (*numbers):       # why use * key and values multiples then **

    c = sum(numbers)
    return c

# %%
add(1,2,3,4,5,6,7,8,0,6,43,2,1,34,5,6,77,4,)
# Out:
# 214

# %%
# type 6 - **kwargs uses for multiple key value 

# call the function 
info(name= "nayan",address ="plot 8 c dighori villa no 8",city= "nagpur ",course= "DS",mentor_name = 'sumit sir sartale' )

# %%
def info(**details):
      for key,value  in details.items():

          return f"key : {key} : value{value}"
info(name= "nayan", address ="plot 8 c dighori villa no 8",city= "nagpur ",course= "DS",mentor_name = 'sumit sir sartale')
# Out:
# 'key : name : valuenayan'

# %%
info("name": "nayan", address ="plot 8 c dighori villa no 8",city= "nagpur ",course= "DS",mentor_name = 'sumit sir sartale' )
# Out:
# 'key : name : valuenayan'

# %%
dict = {"name: "sumit", ""}

# %% [markdown]
# # dict: items

# %% [markdown]
# # type 7 Return Value
# # function gives a result you can store or use

# %%
# is instant for two input , types
