# %% [markdown]
# # 20 Practical Questions on Python Lists #

# %% [markdown]
# ## Easy Level (1-8) ##

# %%
# 1. Create a list named students with 5 student names and print it.

# %%
list = ["nayan","sumit","chetan","piyush","aman"]
list
# Out:
# ['nayan', 'sumit', 'chetan', 'piyush', 'aman']

# %%
# 2. Create a list numbers = [10, 20, 30, 40, 50] and print its type and
# length using len().

# %%
list = [10,20,30,40,50 ]
type(list)
# Out:
# list

# %%
len(list)
# Out:
# 5

# %% [markdown]
# # 3. Create an empty list and append 3 numbers into it using append().

# %%
fruit = []
item = ["mango","banana","orange"]
fruit.append(item)
print(fruit)
# Out:
# [['mango', 'banana', 'orange']]

# %% [markdown]
# # 4. Given lst = [1, 2, 3], use extend() to add [4, 5, 6] to it.

# %%
lst = [1,2,3]
lst1 = [4,5,6]
lst.extend(lst1)
print(lst)
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
#  # 5. Use insert() to add number 100 at index 2 in the list [10, 20, 30, 40].

# %%
list = [10,20,30,40] 
list.insert(2,"100")
list
# Out:
# [10, 20, '100', 30, 40]

# %% [markdown]
# # 6. Remove the element 50 from the list [10, 20, 50, 30, 50] using
# # remove().

# %%
list = [10,20,50,30,50]
list.remove(50)
list
# Out:
# [10, 20, 30, 50]

# %% [markdown]
# # 7. Use pop() to remove the last element from lst = [5, 10, 15, 20] and
# # print the list.

# %%
list2 = [5,10,15,20]
list2.pop(3)
list2
# Out:
# [5, 10, 15]

# %% [markdown]
# # 8. Clear all elements from the list data = [1, 2, 3, 4, 5] using clear().

# %%
list =  [1, 2, 3, 4, 5] 
list.clear()
list
# Out:
# []

# %% [markdown]
# # Medium Level (9-15)
# # 9. Find the index of 25 in the list [10, 15, 25, 30, 40] using index().

# %%
list = [10,15,25,30,40]
list.index(25)
# Out:
# 2

# %% [markdown]
# # 10. Count how many times 7 appears in the list [7, 2, 7, 5, 7, 8] using
# # count().

# %%
list = [7,2,7,5,7,8] 
list.count(7)
# Out:
# 3

# %% [markdown]
# # 11. Sort the list [45, 12, 78, 23, 56] in ascending order using sort().

# %%
list = [45,12,78,23,56]
list.sort()
list
# Out:
# [12, 23, 45, 56, 78]

# %% [markdown]
# # 12. Sort the list [45, 12, 78, 23, 56] in descending order.

# %%
list = [45,12,78,23,56]
list.sort(reverse = True)
list
# Out:
# [78, 56, 45, 23, 12]

# %% [markdown]
# # 13. Reverse the list fruits = ["apple", "banana", "mango", "orange"] using
# # reverse().

# %%
fruits = ["apple","banana","mango","orange"]
fruits.reverse()
fruits
# Out:
# ['orange', 'mango', 'banana', 'apple']

# %% [markdown]
# # 14. Create a copy of list original = [1, 2, 3, 4] using copy() and print both.

# %%
list = [1,2,3,4]
list
# Out:
# [1, 2, 3, 4]

# %%
list.copy()
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# # 15. Take a sentence from user (e.g. "I love Python programming") and
# # convert it into a list of words using split().

# %%
list = input(["enter"])
list = list.split()
list
# Out:
# ['enter'] I love Python programming
# ['I', 'love', 'Python', 'programming']

# %% [markdown]
# # Hard / Mixed Level (16-20)
# # 16. Create a list of 5 numbers. Append 3 more numbers, then sort it in
# # descending order.

# %%
list = [1,2,3,4,5]
list.append(6)
list.append(7)
list.append(8)
list
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
list.sort(reverse = True)
list
# Out:
# [8, 7, 6, 5, 4, 3, 2, 1]

# %% [markdown]
# # 17. Create a list. Insert "Python" at index 0, then remove the last element
# # using pop(), and print the length.

# %%
list = ["I","love","programming"]
list.insert(0,"python")
list
# Out:
# ['python', 'I', 'love', 'programming']

# %%
list.pop(3)
# Out:
# 'programming'

# %%
len(list)
# Out:
# 3

# %% [markdown]
# # 18. Take 5 city names as input from user and store them in a list. Then
# # print them in reverse order.

# %%
list1 = input("enter city1")
list2 = input("enter city2")
list3 = input("enter city3")
list4 = input("enter city4")
list5 = input("enter city5")
list_1 = [list1,list2,list3,list4,list5]
print(list_1)
list_1.sort(reverse = True)
list_1
# Out:
# enter city1 nagpur
# enter city2 hydr
# enter city3 pune
# enter city4 mumbai
# enter city5 bang
# ['nagpur', 'hydr', 'pune', 'mumbai', 'bang']
# ['pune', 'nagpur', 'mumbai', 'hydr', 'bang']

# %% [markdown]
# # 19. Given data = [10, 20, 30, 20, 40, 20], remove all occurrences of 20
#  # (use loop or multiple remove).

# %%
data = [10, 20, 30, 20, 40, 20]
data.remove(20)
print (data)
# Out:
# [10, 30, 20, 40, 20]

# %%
data.remove(20)
data
# Out:
# [10, 30, 40, 20]

# %%
data.remove(20)
data
# Out:
# [10, 30, 40]

# %% [markdown]
# # 20. Create a list of student marks. Sort it, find the highest and lowest
# # mark using list methods, and print them.

# %%
list1 = [10,5,35,40,50]
list1.sort()
list1
# Out:
# [5, 10, 35, 40, 50]

# %%
print ("heighest marks :-",list1.pop())
# Out:
# heighest marks :- 40

# %%
print("lowest marks:-",list1.pop(0))
# Out:
# lowest marks:- 10

# %%
list1
# Out:
# [10, 35, 40]
