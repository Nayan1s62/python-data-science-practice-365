# %%
 # dark green is keywords 
# green is functions 
lists = [1,2,3,"sumit", 24.5]
lists
# Out:
# [1, 2, 3, 'sumit', 24.5]

# %%
type(lists)
# Out:
# list

# %%
# methods 
# list methods are the build in functions used to modify the data and 
print("my list : ",lists)    # to add some extra text and variable that time used print
# Out:
# my list :  [1, 2, 3, 'sumit', 24.5]

# %%
lists
# Out:
# [1, 2, 3, 'sumit', 24.5]

# %% [markdown]
# # list methods

# %%
# append methods add the elements end ot the list 
# append (elements)  at a time single element at end of the list  at a time

# %%
list1 = ["p",22,"b",45.5,"hyd",99]

# %%
list1.append(23)
list1
# Out:
# ['p', 22, 'b', 45.5, 'hyd', 99, 23]

# %%
fruits = ["apple","mango","Graps","banana"]

cars = ["BMW","Thar","KIA","NISAM"]
fruits.append(cars)    # added 2 brackets with together

# %%
fruits   # print 2 list at a time but
# Out:
# ['apple', 'mango', 'Graps', 'banana', ['BMW', 'Thar', 'KIA', 'NISAM']]

# %% [markdown]
# # extend method        # add multiple items use extend

# %%
# he adds the element in itrative methods

# %%
Fruits = ["apple","mango","Graps","banana"]

Cars = ["BMW","Thar","KIA","NISAM"]

Fruits.extend(["sumit", "mukesh","Nayan"])  # extends ony add 1 item at a time so it dost not add multiple item ata time

# %%
Fruits
# Out:
# ['apple', 'mango', 'Graps', 'banana', 'sumit', 'mukesh', 'Nayan']

# %%
len(Cars)
# Out:
# 4

# %%
len(Fruits)
# Out:
# 7

# %%
car = "bmw"
len(car)
# Out:
# 3

# %%
# task create a one name list :-  3 names 
# add the one names using append 
# add the two names using append 
# add the one name using extend 
# add the two name using extend

# %%
name = ["nayan","yash","punit"]
name.append("himanshu")
print(name)
# Out:
# ['nayan', 'yash', 'punit', 'himanshu']

# %%
boys = ["sumit","nanu"]
name.append("boys")
print(name)
# Out:
# ['nayan', 'yash', 'punit', 'himanshu', 'boys', 'boys']

# %%
name = ["nayan","yash","punit"]  #correction 
name.extend("himanshu")
print(name)
# Out:
# ['nayan', 'yash', 'punit', 'h', 'i', 'm', 'a', 'n', 's', 'h', 'u']

# %%
boys = ["sumit","nanu"]   # coorection
name.extend("boys")
print(name)
# Out:
# ['nayan', 'yash', 'punit', 'h', 'i', 'm', 'a', 'n', 's', 'h', 'u', 'b', 'o', 'y', 's']

# %% [markdown]
# # insert method  : the insert method insert the specified value at the specific

# %%
Fruits = ["apple","mango","Graps","banana"]

# syntax list.insert(index-pos,elmnt) #

fruits.insert(11,"sumit")

# %%
Fruits
# Out:
# ['apple', 'mango', 'Graps', 'banana', 'sumit', 'mukesh', 'Nayan']

# %%
 # if position is availabe add that if not add at last in inser method

# %%
# remove method ; - remove method removes the first occurance of the first element 

# remove only remove the directly value

# %%
Fruits = ["apple","mango","apple","Graps","banana"]
# remove the apple elements 

Fruits.remove("apple")
Fruits
# Out:
# ['mango', 'apple', 'Graps', 'banana']

# %%
Fruits = ["apple","mango","apple","Graps","banana"]
# remove the apple elements 

Fruits.remove("apple","mango")       # does not allow to remove 2 elements 
Fruits
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 4
#       1 Fruits = ["apple","mango","apple","Graps","banana"]
#       2 # remove the apple elements
# ----> 4 Fruits.remove("apple","mango")
#       5 Fruits
#
# TypeError: list.remove() takes exactly one argument (2 given)

# %%
Fruits = ["apple","mango","apple","Graps","banana"]
# remove the apple elements 

Fruits.remove("apple")
Fruits

# %% [markdown]
# # pop method : - add the specific position of value
# # pop is remove element at the specific position

# %%
Fruits = ["apple","mango","apple","Graps","banana"]
Fruits.pop(3)  # if not give any index remove last item in the list 
                # if we give out of the element 11 so he saw error 
Fruits
# Out:
# ['apple', 'mango', 'apple', 'banana']

# %%
Fruits = ["apple","mango","apple","Graps","banana"]
Fruits.pop()  # if not give any index remove last item in the list 
                # if we give out of the element 11 so he saw error 
Fruits
# Out:
# ['apple', 'mango', 'apple', 'Graps']

# %%
Fruits = ["apple","mango","apple","Graps","banana"]
Fruits.pop(11)  # if not give any index remove last item in the list 
                # if we give out of the element 11 so he saw error 
Fruits
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[37], line 2
#       1 Fruits = ["apple","mango","apple","Graps","banana"]
# ----> 2 Fruits.pop(11)  # if not give any index remove last item in the list
#       3                 # if we give out of the element 11 so he saw error
#       4 Fruits
#
# IndexError: pop index out of range

# %%
Fruits = ["apple","mango","apple","Graps","banana"]
Fruits.remove(4)  # if not give any index remove last item in the list 
                # if we give out of the element 11 so he saw error 
print(Fruits)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 2
#       1 Fruits = ["apple","mango","apple","Graps","banana"]
# ----> 2 Fruits.remove(4)  # if not give any index remove last item in the list
#       3                 # if we give out of the element 11 so he saw error
#       4 print(Fruits)
#
# ValueError: list.remove(x): x not in list

# %% [markdown]
# # clear() method ;- remove all the item from the list the clear method is used

# %%
Fruits = ["apple","mango","apple","Graps","banana"]

Fruits.clear()      
Fruits
# Out:
# []

# %% [markdown]
# # index () method :- find the specific position of value

# %%
# display the value position 
Fruits = ["apple","mango","apple","Graps","banana"]

Fruits.index(4)     
Fruits
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 3
#       1 Fruits = ["apple","mango","apple","Graps","banana"]
# ----> 3 Fruits.index(4)
#       4 Fruits
#
# ValueError: 4 is not in list

# %%
# specific position value find 
# syntax : - list [position_index]

# %%
Fruits = ["apple","mango","apple","Graps","banana"]

Fruits.index("banana")      # only return the number at that position
# Out:
# 4

# %%
Fruits[4]    # only return the charater at that position
# Out:
# 'banana'

# %%
name = ["sumit","neha","swati","rahul","yash"]
name.index("neha")   # it is the index we got value
# Out:
# 1

# %%
name = ["sumit","neha","swati","rahul","yash"]
name[1]  # it is list index method
# Out:
# 'neha'

# %%
name = ["sumit","neha","swati","rahul","yash"]
name[122]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[48], line 2
#       1 name = ["sumit","neha","swati","rahul","yash"]
# ----> 2 name[122]
#
# IndexError: list index out of range

# %%
name = ["sumit","neha","swati","rahul","yash"]
name.index("bananas")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 2
#       1 name = ["sumit","neha","swati","rahul","yash"]
# ----> 2 name.index("bananas")
#
# ValueError: 'bananas' is not in list

# %%
Fruits = ["apple","mango","apple","Graps","banana"]
Fruits.index("apple")
# Out:
# 0

# %%
Fruits[1]
# Out:
# 'mango'

# %% [markdown]
# # count() method :- specifi values how many times are comes he retuns the ans in number how much time the values are repeted

# %%
Fruits = ["apple","mango","apple","Graps","banana"]
Fruits.count("apple")
# Out:
# 2

# %%
Fruits = ["apple","mango","apple","Graps","banana"]
Fruits.count("mango")
# Out:
# 1

# %%
Fruits = ["apple","mango","apple","Graps","banana"] # if the values is not there present then it shows 0 in out put 
Fruits.count("nayan")
# Out:
# 0

# %%
Fruits = ["apple","mango","apple","Graps","banana"]  # at a time we can chek only one value in list throuth the count method 
Fruits.count("mango","apple")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 2
#       1 Fruits = ["apple","mango","apple","Graps","banana"]
# ----> 2 Fruits.count("mango","apple")
#
# TypeError: list.count() takes exactly one argument (2 given)

# %%
Fruits = ["apple","mango","apple","Graps","banana"]  # at a time we can chek only one value in list throuth the count method 
Fruits.count(["mango","apple"])  # no error but ans is become a 0 in list
# Out:
# 0

# %% [markdown]
# # sort () method : - order the list elements
#
# # syntax : - list.sort(reverse = True/False ) #

# %%
Age = [20,34,54,34,67]  # assending comes in by default no need to parameter  

Age.sort()
Age
# Out:
# [20, 34, 34, 54, 67]

# %%
Age = [20,34,54,34,67]

Age.sort( reverse = True)        # decending order can print using this 
Age
# Out:
# [67, 54, 34, 34, 20]

# %%
Fruits = ["apple","mango","apple","Graps","banana"]   # try one more time 

Fruits.sort()
Fruits
# Out:
# ['Graps', 'apple', 'apple', 'banana', 'mango']

# %%
Fruits = ["apple","mango","apple","Graps","banana"]    # try one more time 

Fruits.sort(reverse = True)
Fruits
# Out:
# ['mango', 'banana', 'apple', 'apple', 'Graps']

# %%
list2 = [11,21,10,2.3,34,5,33.4]            #  number are possibles 
list2.sort()
list2
# Out:
# [2.3, 5, 10, 11, 21, 33.4, 34]

# %%
list1 = [11,21,10,2.3,34,5,33.4]
list2 = list1.copy()
list2
# Out:
# [11, 21, 10, 2.3, 34, 5, 33.4]

# %% [markdown]
# # string formating part
# # i have two variables

# %%
Name = "sumit"

Age = 10

print(f"Hi , i am {Name} and {Age} ")  # in currly bracket use f "******"
# Out:
# Hi , i am sumit and 10

# %%
a =10
b= 20
c = a + b 
print("addiction is",c)
# Out:
# addiction is 30

# %%
a = 10

# chek the even value 
# use string formation print answer even or odd
even_odd = a % 2 == 0 
even_odd
# Out:
# True

# %%
A = 10

result  = "yes"* (A % 2 == 0 ) or "NO " 

print (f"A number is Even : {result} and  A is not ODD {result}")
# Out:
# A number is Even : yes and  A is not ODD yes

# %%
"1" or "NO"
# Out:
# '1'
