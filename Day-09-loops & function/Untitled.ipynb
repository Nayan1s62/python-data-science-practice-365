# %%
for a in range(1,21,2):
    print("Hello World",a)
# Out:
# Hello World 1
# Hello World 3
# Hello World 5
# Hello World 7
# Hello World 9
# Hello World 11
# Hello World 13
# Hello World 15
# Hello World 17
# Hello World 19

# %%
for a in range(21):
    if a == 5:
        continue  # a 5 wala gayab hogaya bhai 
        print("Hello World",a)
# Out:
# Hello World 0
# Hello World 1
# Hello World 2
# Hello World 3
# Hello World 4
# Hello World 6
# Hello World 7
# Hello World 8
# Hello World 9
# Hello World 10
# Hello World 11
# Hello World 12
# Hello World 13
# Hello World 14
# Hello World 15
# Hello World 16
# Hello World 17
# Hello World 18
# Hello World 19
# Hello World 20

# %%
# natural no 1-9

# %%
for i in range (1,10):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
# break # continue both we can use
