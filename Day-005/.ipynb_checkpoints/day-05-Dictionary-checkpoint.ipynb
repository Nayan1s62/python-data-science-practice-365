# %% [markdown]
# # Here are 20 Practical Questions on Dictionary and Tuple #
# # Easy Level (1-8)

# %% [markdown]
# # 1. Create a dictionary student with keys: "name", "age", "city" and print it.

# %%
student = {"name":"age","city":10 }
print(student)
type(student)
# Out:
# {'name': 'age', 'city': 10}
# dict

# %% [markdown]
# # 2. Given d = {"a": 1, "b": 2, "c": 3}, print all keys using keys() method.

# %%
d = {"a": 1, "b": 2, "c": 3}
d.keys()
# Out:
# dict_keys(['a', 'b', 'c'])

# %%
# 3. Given d = {"a": 1, "b": 2}, print all values using values() method.

# %%
d = {"a": 1, "b": 2}
d.values()
# Out:
# dict_values([1, 2])

# %% [markdown]
# # 4. Use get() method to safely get the value of key "name" from dictionary
#  # d = {"name": "Sumit", "age": 25}.

# %%
d = {"name": "Sumit", "age": 25}
d.get("name")
# Out:
# 'Sumit'

# %% [markdown]
# # 5. Create a tuple with 5 numbers and print its type and length.

# %%
tup = (1,2,3,4,5)
type(tup)
# Out:
# tuple

# %%
len(tup)
# Out:
# 5

# %% [markdown]
#  # 6. Create a tuple tup = (10, 20, 30, 40, 50) and use count() to count how
#  # many times 20 appears.

# %%
tup = (10, 20, 30, 40, 50)
tup.count(20)
# Out:
# 1

# %% [markdown]
# # 7. Use index() method on tuple (10, 20, 30, 40) to find the position of 30.

# %%
tup = (10,20,30,40)
tup.index(30)
# Out:
# 2

# %% [markdown]
# # 8. Create an empty dictionary and add 3 key-value pairs using
# # assignment.

# %%
dict1 = {               }
dict1.update({"car":"bmw","home":"btown","salary":"10000"})

dict1
# Out:
# {'car': 'bmw', 'home': 'btown', 'salary': '10000'}

# %% [markdown]
# # Medium Level (9-15)

# %% [markdown]
# # 9. Given d = {"a": 1, "b": 2}, use update() to add {"c": 3, "d": 4}.

# %%
d = {"a": 1, "b": 2} 
d.update({"c":3,"d":4})
d
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %% [markdown]
#  # 10. Remove the key "age" from dictionary student = {"name": "Rahul",
#  # "age": 22, "city": "Delhi"} using pop().

# %%
student = {"name": "Rahul","age":22,"city": "Delhi"}
student.pop("age")
print(student)
# Out:
# {'name': 'Rahul', 'city': 'Delhi'}

# %% [markdown]
# # 11. Use popitem() on dictionary d = {"x": 10, "y": 20, "z": 30} and print the
# # removed item.

# %%
d = {"x": 10, "y": 20, "z": 30}
d.popitem()
# Out:
# ('z', 30)

# %% [markdown]
# # 12. Create a copy of dictionary original = {"a": 1, "b": 2} using copy()
# # method.

# %%
original = {"a": 1, "b": 2}
original_ = original.copy()
original_
# Out:
# {'a': 1, 'b': 2}

# %%
original
# Out:
# {'a': 1, 'b': 2}

# %% [markdown]
# # 13. Use fromkeys() to create a dictionary with keys ["red", "green",
# # "blue"] and default value 0.

# %%
keys = {"red","green","blue"}
dict1 = dict.fromkeys(keys,0)
dict1
# Out:
# {'blue': 0, 'green': 0, 'red': 0}

# %%
# 14. Create a tuple with mixed data types and try to change one element
# (show error).

# %%
tuple1 = (1,2,3,"name")
print(tuple1)
# Out:
# (1, 2, 3, 'name')

# %%
tuple1.update("4")
tuple1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 tuple1.update("4")
#       2 tuple1
#
# AttributeError: 'tuple' object has no attribute 'update'

# %%
# 15. Given d = {"name": "Sumit"}, use setdefault("age", 25) and print the
# dictionary.

# %%
d = {"name": "Sumit"}
d.setdefault("age",25)
d
# Out:
# {'name': 'Sumit', 'age': 25}

# %%
type(d)
# Out:
# dict

# %% [markdown]
# # Hard / Mixed Level (16-20)

# %% [markdown]
# # 16. Create a dictionary. Add 3 items using update(), then remove the last
# # inserted item using popitem().

# %%
dict2 = {  }
dict2.update({"flat":"2","rooms":"3","house":"30000"})  # to add some this u need to use {} in added bracket 
print(dict2)
# Out:
# {'flat': '2', 'rooms': '3', 'house': '30000'}

# %% [markdown]
# # 17. Create a tuple of 6 numbers. Find the index of a number and count
#  # how many times it appears.

# %%
tup1 = (1,5,3,2,4,2,6)
tup1.index(2)
# Out:
# 3

# %%
tup1.count(2)
# Out:
# 2

# %% [markdown]
# # 18. Take 3 student names and marks as input and store them in a
# # dictionary (name as key, mark as value).

# %%
student1 = input("enter names1 ")
student2 = input("enter names2 ")
student3 = input("enter names3 ")
marks1 = input("enter marks1 ")
marks2 = input("enter marks2 ")
marks3 = input("enter marks3 ")
student = student1,student2,student3
marks = marks1,marks2,marks3
student1.dict = {"student","marks"}
marks.dict ={"student","marks"}
print(student),print(marks)
# Out:
# enter names1  nayan
# enter names2  paritosh
# enter names3  yash
# enter marks1  40
# enter marks2  33
# enter marks3  44
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[84], line 9
#       7 student = student1,student2,student3
#       8 marks = marks1,marks2,marks3
# ----> 9 student1.dict = {"student","marks"}
#      10 marks.dict ={"student","marks"}
#      11 print(student),print(marks)
#
# AttributeError: 'str' object has no attribute 'dict' and no __dict__ for setting new attributes

# %% [markdown]
# # 19. Given data = {"a": 10, "b": 20, "c": 10}, use items() and print only
# # keys where value is 10.

# %%
data1 = {"a": 10, "b": 20,"c":30}
data1.items()
# Out:
# dict_items([('a', 10), ('b', 20), ('c', 30)])

# %%
data1.i
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data1.index({0})
#
# NameError: name 'data1' is not defined

# %% [markdown]
# #  20. Create a dictionary of 5 items, make a copy, clear the original
# # dictionary, and show both.

# %%
dict1 = {"marks":22,"subject":5,"teacher":3,"schoolplot no ":22,"eligibility":18}
dict2 = dict1.copy()
dict1
# Out:
# {'marks': 22,
#  'subject': 5,
#  'teacher': 3,
#  'schoolplot no ': 22,
#  'eligibility': 18}

# %%
dict2
# Out:
# {'marks': 22,
#  'subject': 5,
#  'teacher': 3,
#  'schoolplot no ': 22,
#  'eligibility': 18}

# %% [markdown]
# # 21. (Hard) Create a dictionary student with 4 key-value pairs. Then use
# # update() to add another dictionary, remove the last item using popitem(),
# # and finally print all items using items().

# %%
student = {"a":100,"b":200,"c":300,"d":400}
student.update({"r":500,"l":600,"k":700})
student
# Out:
# {'a': 100, 'b': 200, 'c': 300, 'd': 400, 'r': 500, 'l': 600, 'k': 700}

# %% [markdown]
# # 22. (Hard) Create a tuple with 8 numbers. Find the index of the number
# # 25. If it exists, count how many times it appears. Then convert the tuple
# # into a list, sort it in descending order, and print.

# %%
tup1 = (10,20,25,30,35,40,45,50)
tup1.index(25)
# Out:
# 2

# %%
tup2 =list (tup1)
tup2
# Out:
# [10, 20, 25, 30, 35, 40, 45, 50]

# %%
tup2.sort(reverse = True)
tup2
# Out:
# [50, 45, 40, 35, 30, 25, 20, 10]

# %% [markdown]
# # 23. (Hard) Take 4 student names and their marks as input from the user.
# # Store them in a dictionary (name as key, marks as value). Then find and
# # print the student with the highest marks.

# %%
name = input("enter")
marks = int(input("enter mark"))
dict1 = (name,marks)
dict1
# Out:
# enter nayan
# enter mark 100
# ('nayan', 100)

# %% [markdown]
# # 24. (Hard) Create a dictionary info = {"name": "Aman", "age": 21, "city":
# # "Mumbai"}. Make a copy of it. Clear the original dictionary. Then add a
# # new key "country": "India" in the copy and print both dictionaries.

# %%
info = {"name": "Aman", "age": 21, "city": "Mumbai"}
data = info.copy()
data
# Out:
# {'name': 'Aman', 'age': 21, 'city': 'Mumbai'}

# %%
info.clear()

# %%
key = {"country": "India"}
data.update(key)
data
# Out:
# {'name': 'Aman', 'age': 21, 'city': 'Mumbai', 'country': 'India'}

# %%
 # 25. (Hard) Given data = (10, 20, 30, 20, 40, 20, 50), convert it into a
# dictionary where key is the number and value is its count of occurrences
# (using tuple methods + dictionary)
