# %% [markdown]
# # list of list (nested list )

# %%
list1 = [1,2,3,4,5,6]

# nested list (list of list )

list2 = [[1,2,3],[4,5,6],[7,8,9]]
  # (0,0) (0,1)  (0,2)
list2 [2] [0]
# Out:
# 7

# %%
list1 = [1,2,3,4,5,6]

# nested list (list of list )

list2 = [[1,2,3],[4,5,6],[7,8,9]]
  # (0,0) (0,1)  (0,2)
list2 [2] [0] = 10 # list is mutable thing we can add and change the values in list 
list2
# Out:
# [[1, 2, 3], [4, 5, 6], [10, 8, 9]]

# %% [markdown]
# # tuple method : - it inmutable data type ( unchangeable )
# # a tuple another sepuence data type that is similar to the list
# # seprate number by ,
# # enclosed in paranthesis
# # list are closed in[] # tuple are in () parantheses and can not be updated
# # tuple can be thought of as read
#  # tuple seperate the value using comma

# %%
tuple1 = ("praful",22,"bharat",45.5,"vadodara",99)   # , is mandatory in values between

# %%
A = [20] # int 
tuple(A)  # tuple seperate the value using comma
# Out:
# (20,)

# %%
A = (20,10) # int  # need comma between two values 
type(A)  # tuple seperate the value using comma
# Out:
# tuple

# %%
A = (20,10) # int  # need comma between two values 
list(A)  # tuple seperate the value using comma
# Out:
# [20, 10]

# %%
tup = ("praful",22,"bharat",45.5,"vadodara",99)   # , is mandatory in values between # cout , len(), index(),type()
tup.index(22)
# Out:
# 1

# %%
tup.remove(22) # tuple not allows the methods to chang and operation
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 tup.remove(22)
#
# AttributeError: 'tuple' object has no attribute 'remove'

# %% [markdown]
# # dictionary data type
# # it is collection of data stored in form of key - value pairs
# # it is written usin g curly braces {} like name {"name":"sumit":"age":20}
# # each key must be unique , but values can be duplicate .
# # it is mutable meaning you can add update or delete items
# # values are acces using keys, like d["name "].
# # every thing can change and happend using key
#
# # methods of dictionary 1)clear , 2)copy , 3)get 4)key 5)update 6)value 7)fromkeys

# %%
dict1 = {"Name":"Sumit","Age":10, "Mob-NO ":123} # key always in "" braces 
print(type(dict1))
# Out:
# <class 'dict'>

# %% [markdown]
# # fromkeys () methods

# %%
# fromkeys () methods 

keys = ["Name","Age","Mob-no"]

dict2 = dict.fromkeys (keys,0)   # accept only 2 arrguments at a time

# %%
dict2
# Out:
# {'Name': 0, 'Age': 0, 'Mob-no': 0}

# %%
# fromkeys () methods 

keys = ["Name","Age","Mob-no"]
values = ["sumit",10,123]

dict2 = dict.fromkeys (keys,values)

# %%
dict2
# Out:
# {'Name': ['sumit', 10, 123],
#  'Age': ['sumit', 10, 123],
#  'Mob-no': ['sumit', 10, 123]}

# %%
key1 = ["A","B","c"]
values = 20
dict3 = dict.fromkeys (key1,values)   # uses key values pairs for the each keys and same values 
dict3
# Out:
# {'A': 20, 'B': 20, 'c': 20}

# %%
key1 = ["A","B","c"]
values = 20
dict3 = dict.fromkeys (["A","B","c"],values)   # uses key values pairs for the each keys and same values 
dict3
# Out:
# {'A': 20, 'B': 20, 'c': 20}

# %%
# key()
Dict3 = {"Name":10 ,"Age":10,"Mob-NO":10 }   #  Dictionary  
Dict3.keys()
# Out:
# dict_keys(['Name', 'Age', 'Mob-NO'])

# %% [markdown]
# # values methods  : acces the all value of dict

# %%
# values methods  : acces the all value of dictionary 

Dict3.values()
# Out:
# dict_values([10, 10, 10])

# %% [markdown]
# # get method : he returned the key value

# %%
Dict3.get("Name")
# Out:
# 10

# %%
print(Dict3.get("Mob-NO"))
# Out:
# 10

# %% [markdown]
# # item () methods

# %%
Dict3.items()      # it is a key we can acces the value
# Out:
# dict_items([('Name', 10), ('Age', 10), ('Mob-NO', 10)])

# %% [markdown]
# # pop() method remove the charater \ item from the dictionary using key name  multiple at once

# %%
Dict4 = {"car":"Thar","Model":2026 , "color":"Black"}



Dict4.pop("Model")    # not use any item he removes last items 
Dict4
# Out:
# {'car': 'Thar', 'color': 'Black'}

# %%
Dict4 = {"car":"Thar","Model":2026 , "color":"Black"}


Dict4.popitem()  # it dont take any argument he knows that he need to pop last key pair 
Dict4
# Out:
# {'car': 'Thar', 'Model': 2026}

# %% [markdown]
# # pop vs popitem diffrence

# %% [markdown]
# # update () methods :

# %%
Dict4 = {"car":"Thar","Model":2026 , "color":"Black"}

Dict4.update({"Engine_size": "20lit" })  # added the new item using update method 
Dict4
# Out:
# {'car': 'Thar', 'Model': 2026, 'color': 'Black', 'Engine_size': '20lit'}

# %%
Dict4 = {"car":"Thar","Model":2026 , "color":"Black"}
Dict4["Engine_size"] = "20lit" # added new value at last 
Dict4
# Out:
# {'car': 'Thar', 'Model': 2026, 'color': 'Black', 'Engine_size': '20lit'}

# %%
Dict4 = {"car":"Thar","Model":2026 , "color":"Black"}
Dict4["car"] = "brezza" # update value 
Dict4
# Out:
# {'car': 'brezza', 'Model': 2026, 'color': 'Black'}

# %%
Dict4 = {"car":"Thar","Model":2026 , "color":"Black"}
Dict4["cars"] = "brezza" # update value  if the thing is new "cars" # if key is available update other vise create a new variablr pair 
Dict4
# Out:
# {'car': 'Thar', 'Model': 2026, 'color': 'Black', 'cars': 'brezza'}

# %%
Dict4 = {"car":"Thar","Model":2026 , "color":"Black"}
Dict4["Engine_size"] = "20lit" # added new value at last 
Dict4
