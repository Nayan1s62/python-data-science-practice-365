# %% [markdown]
# # nested condition  # if else &

# %%
if condiction 
  if condiction : True
   # block of code 
  else:
# block of code

# %%
age = 18 
ID = True

if age >= 18 and ID == True:
    print("Allow")
else :
    print("not allow ")
# Out:
# Allow

# %%
Age = 18
ID = True

if Age >= 18:
 if ID == True:
    print("Allow")
 else :
    print("Bring the ID  ")
else:
    print("Not allow ")
# Out:
# Allow

# %%
student_marks = 80  

if student_marks >= 45:
    if student_marks >= 80:
    print("excellent marks ")
else:
    print("Failed ")
else:
    print(" fail")
# Out:
#   Cell In[21], line 5
#     print("excellent marks ")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 4

# %%
age = 18 
ID = True

if age >= 18 and ID == True:
    print("Not eligible for vote ")
else :
    print("eligible for vote ")

# %%
A = 10 
B = 20
C = 30
 if A>=B :
if A>=C:
     print("excellent marks) 
else :

# %%
# user want to withdraw money
pin = "1234"
amp = 5000
atmpin = int(input("enter pin"))
amont = int(input("amount"))
if atmpin == pin :
    if amont >= amp:
        print("atm amount is sufficient")
    else :
        print("atm pin is incorrect")
else:
    print("atm amount is insufficient")
# Out:
# enter pin 1234
# amount 1000
# atm amount is insufficient

# %%
# user want to withdraw money
pin = 4952
amount = 5000
atmpin = int(input("enter pin"))
amount = int(input("amount"))
if atmpin == pin :
    print("atm pin is correct")
    if amount >= amount:
        print("atm amount is sufficient")
    else :
        print("atm pin is incorrect")
else:
    print("atm amount is insufficient")

# %%
user = "nayan1s62"
password = 12345

user1 = input("enter user name ")
password1 = int(input ("enter password"))
if user1 == user:
    print(" user name is correct ")
    if password1 == password :
        
        print(" login successfully ")
    else:
        print("Invalid password is not correct",user1)
else:
     print("the user password is in correct",password)
# Out:
# enter user name  punitbro
# enter password 12345
# the user password is in correct 12345

# %%
user = "nayan1s62"
password = 12345

user1 = input("enter user name ")
password1 = int(input ("enter password"))
if user1 == user:
    password1 = int(input ("enter password"))
    if password1 == password :
        
        
        print(" login successfully ")
    else:
        print("Invalid name is not correct:- ",password)
else:
     print("the user name  is incorrect:- ",user1)
# Out:
# enter user name  nayan
# enter password 1234
# the user name  is incorrect:-  nayan

# %%
# civil score 
# chek the  annual income 
# civil score to approve the loan 
incomeal = 300000
score = 730
annual_income = int(input("enter the income "))
if  annual_income >= incomeal :
    civil_score = int(input("enter the score"))
    if civil_score >= score :
         print("loan approved")
    else:
         print("loan civil score is not good ",civil_score )
else:
        print("Loan annual income is not  more than 3 lakh not valid ",annual_income)
# Out:
# enter the income  400000
# enter the score 730
# loan approved

# %%
num = int(input("enter age "))

if num >= 18 :
    print("the voter is eligible to vote ")
else:
          print("the voter is not eligible to vote ")
# Out:
# enter age  17
# the voter is not eligible to vote
