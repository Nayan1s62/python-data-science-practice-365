# %%
nayan_12 = 23

# %%
print (nayan)
# Out:
# 23

# %%
c3 = 300
print (c3)
# Out:
# 300

# %%
a = 500
print (a)
# Out:
# 500

# %%
help ("keywords")
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %%
false = ( " nayan" )
print ( false )
# Out:
#  nayan

# %%
str= input("enter the input ")
# Out:
# enter the input  hello nayan bro how are you how was going on

# %%
# store the user name 

name = ("nayan")

# display user name 
print (name )
# Out:
# nayan

# %%
""" the mathamatics formula applying for the finding area of circle """
radius = 5
area = 3.14 * radius * radius 
print (area)
# Out:
# 78.5

# %%
# take user name and display output 
name = input("enter : ")
age = 22
cgpa = 7.10
print (name,age,cgpa)
# Out:
# enter :  nayan44
# nayan44 22 7.1

# %%
x = 10
y = 30
x += y
print (x)
# Out:
# 40

# %%
x -= y 
print (x)
# Out:
# 10

# %%
print(f"Name: {name}, Age: {age}, CGPA: {cgpa}")
# Out:
# Name: nayan44, Age: 22, CGPA: 7.1

# %%
a = int(input("enter the input number1"))
b =int(input(" enter the user input "))
c = a // b
print (c)
# Out:
# enter the input number1 200
#  enter the user input  2
# 100

# %%
# finding area of rectangle and display it on screen 
rectangle = area
area = 11 * 12
print (area)
# Out:
# 132

# %%
# using ** double power arithmatic operators 
num = 5
anser = num ** 4
print (anser)
# Out:
# 625

# %%
# taking user input for display 
num = int(input(" enter number ") )
ans= num**3
print(ans)
# Out:
#  enter number  7
# 343

# %%
# take an a 2 user input then display double output off it

a = int(input(" enter user1 "))
b = int(input(" enter user2 "))
print(a ** b)
# Out:
#  enter user1  2
#  enter user2  4
# 16

# %%
# take an a input and show cube of number 
num = int(input(" take user input"))
cube = num * 3
print( cube)
# Out:
#  take user input 7
# 21

# %%
# take user input and perform addiction 
num1 = int(input("enter user input ")) 
num2 = int(input("enter user input "))
sum = num1 + num2
print(sum)
# Out:
# enter user input  22
# enter user input  24
# 46

# %%
a = 22
b = 1.3
type (b)
# Out:
# float

# %%
num = 20;

if num % 2 == 0:
    print ("Even")
else:
    print ("ODD")
# Out:
# Even

# %%
    print ("odd")
# Out:
# odd
