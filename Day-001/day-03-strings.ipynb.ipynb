# %% [markdown]
# # 1. Logical Operators (and, or, not) Questions #

# %%
# Take age and marks from user.
# Check if the student is eligible for admission:
# Age must be between 18 and 25 AND marks >= 60

Age = int(input("enter your age"))
Marks = int(input("Enter your marks"))
if Age>=18 and Age<=25 and Marks>=60:
   print( " student eligible")
else:
   print("no eligible")
# Out:
# enter your age 22
# Enter your marks 80
#  student eligible

# %%
#Q2
# Take username and password from user.
# Check login:
# Username == "admin" AND Password == "12345"
# Print "Login Successful" or "Login Failed"


userName = str(input("Enter your user name "))
password = int(input("enter your password "))
if userName == "admin" and password == "12345":
     print("login succesfully")

elif  password:
     print("login Fail ")
# Out:
# Enter your user name  nayan
# enter your password  1234567
# login Failed

# %%
 # Python Q3) 
# Take a number from user.
# Check if the number is between 50 and 100 (using 'and')
# Also check if it is NOT divisible by 5 (using 'not')

No = int(input("enter the number"))
if ( No>=50 and No<=100 and not (No % 5 == 0)):
    print("valid no ")
else :
     print("not valid")
# Out:
# enter the number 60
# not valid

# %%
# Question 4:
# Python
# Take three numbers from user.
# Print the largest number using 'and' and 'or' operators.
A = int(input("enter the number user1 "))
B = int(input("enter the number user2 "))
C = int(input("enter the number user 3"))
if ( A >= B and A >= C )  or ( A==B and A>C) or  ( A == C and A>B):
    
     print( "A is largest :", A )
     
elif ( B >= A and B >= C ) or (B == A and B > C ) or ( B == C and  B>A ):
     
     print("B is the largest",B)

else:
     print("C is the largest",C)
# Out:
# enter the number user1  60
# enter the number user2  70
# enter the number user 3 90
# C is the largest 90

# %%
# Question 5 :
#Take your full name as input from user.
# Print the following:
# 1. Full name in uppercase
# 2. Full name in lowercase
# 3. Length of your name
# 4. First 3 characters
# 5. Last 3 characters
Lala = input("enter full name ")
Lala.upper()
# Out:
# enter full name  Nayan samrutwar
# 'NAYAN SAMRUTWAR'

# %%
bala = input("enter your name ")
bala.lower()
# Out:
# enter your name  NAYSAMRUTWAR
# 'naysamrutwar'

# %%
name = input("enter name ")
len(name)
# Out:
# enter name  nayan samrutwa
# 14

# %%
name[11:15]
# Out:
# 'twa'

# %%
# Question 6:-
# Python
# Take any sentence from user.
# Print:
# - First 10 characters
# - Last 10 characters
# - Characters from index 5 to 15
# - Every 2nd character of the sentence

Sentence = input("enter the sentence:-")
Sentence[0:15]
# Out:
# enter the sentence:- Sentenceprogramming and python development matters
# 'Sentenceprogram'

# %%
Sentence[40:]
# Out:
# 'nt matters'

# %%
# Question 7:#
# Python
# Take a word from user.
# Check if the word is a palindrome or not.
# (Example: "madam", "radar")

A = input("enter a word:-")
if A[::-1] == A :
    print("it is palidrom")
else:
    print("it is not palidrom")
# Out:
# enter a word:- raj
# it is not palidrom

# %%
#Question 8:
#Python
# Take email as input (e.g: nayan@gmail.com)
# Print only the username (part before @)

Email = input("enter email")
Email[:5]
# Out:
# enter email nayan.samrutwar@gmail.com
# 'nayan'

# %%
# Print only the domain (part after @)
Email[16:]
# Out:
# 'gmail.com'

# %%
# Bonus Mixed Question (String + Logical) #
# Question 9:
# Python
# Take a password from user.
# Check if password is strong:
# - Length >= 8
# - Contains '@' or '#'
# Print "Strong Password" or "Weak Password"
password = input("enter password :")
if len(password)>= 8 and ( '@'in password or '#' in password ): # in is used to chek that  @, # is in user input or not 
    # len(password) is used to chek leng of charaters user are useing in input

     print("strong password")  

else :
    print("weak password")
# Out:
# enter password : Nayanasdgfds
# weak password

# %%
# Q10
# Python
# Take three subject marks from user (English, Math, Science).
# Check if the student has passed:
# All marks should be >= 40 (use 'and' operator)
# If any one subject is < 40, print "Fail"

E = int (input("enter marks1:- "))
M = int( input("enter marks2:- "))
S = int( input("enter marks3:- "))
if ( E >= 40 and M >= 40 and S >= 40):
     print("pass")

else:(E < 40 and M < 40 and S < 40)
print("Failed ")
# Out:
# enter marks1:-  40
# enter marks2:-  50
# enter marks3:-  4
# Failed

# %%
# Q11. Logical Operators + User Input
#Python
# Take a number from user.
# Check whether the number is:

# Sumit Sir Notes
# Positive AND Even
# OR
# Negative OR Odd
# Print appropriate message

A = int(input("enter the number"))                                 # Common Mistakes to Avoid:

if  ( A>=0 and A % 2 == 0 ):                                           # 3. Don't put a comma in expressions (A % 2, ❌)
    print("The number is positive even ")                               #Even: A % 2 == 0

elif ( A<0 ) or ( A % 2 != 0  ):                                #Use elif for another condition, not else(condition).
 print("the number is negative odd number")                      #  Use != for "not equal", not "not 0".
                                                                  # 5. Odd: A % 2 != 0
        
                                                                   #   Always write complete conditions inside if/elif.
# Out:
# enter the number 33
# the number is negative odd number

# %%
# Q12. String Operations
#Python
# Take your city name as input.
# Print the following:
# 1. City name in reverse order
# 2. Number of vowels in the city name (a,e,i,o,u)
# 3. City name without first and last character

City = input("enter  city name")
City[::-1]
# Out:
# enter  city name Nagpur
# 'rupgaN'

# %%
City[1:5]
# Out:
# 'agpu'

# %%
# dout # 2. Number of vowels in the city name (a,e,i,o,u)
count = 0

for aeiou in City:
    if aeiou in "Nagpur":
        count += 1

print(count)
# Out:
# 6

# %%
#.Q13 String Slicing
# Python
# Take a mobile number as input (10 digits).
# Print:
# First 3 digits (network code)
# Last 4 digits
# Middle 3 digits
Phone = (input("enter 10 digit no"))
Phone[0:4]                                          # First 3 digits (network code)
# Out:
# enter 10 digit no 7775046467
# '7775'

# %%
Phone[6:]   # Last 4 digits of phone no
# Out:
# '6467'

# %%
Phone[4:7]         # Middle 3 digits of phone no
# Out:
# '046'

# %%
#Q13 . Mixed (String + Logical)
#Python
# Take a string from user.
# Check if:
# - The string length is greater than 5

#Sumit Sir Notes
# - AND it starts with 'A' or 'a'
# Print "Valid String" or "Invalid String"


User = input("enter ")
if len(User)>=5 and ('A'in User or 'a' in User):
    print("it is valid string")
else:
    print("Invalid string")
# Out:
# enter  deshbhkti
# Invalid string

# %%
# ended here day 3
